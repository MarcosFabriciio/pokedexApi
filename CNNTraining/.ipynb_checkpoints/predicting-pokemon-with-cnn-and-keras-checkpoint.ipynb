# %% [markdown]
# This kernel is my second attempt on this dataset. On my first attempt I tried to train model that can predict all 149 classes, but I failed because of lack of data - yes, this dataset is imbalanced and almost all classes don't have enough data for training. So, in this case I tried another approach and let's see, what we can do here:

# %%
# Importing all necessary libraries
import numpy as np
import pandas as pd
import cv2 as cv
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import gc
import requests

from PIL import Image
from io import BytesIO

from collections import Counter
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from keras.utils import to_categorical

warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# First of all - let's look at our data, epecially how mach images belong to each class:

# %%
# A little bit of data exploration
path = '../input/pokemon-generation-one/dataset/dataset' # Path to directory which contains classes
classes = os.listdir(path) # List of all classes
print(f'Total number of categories: {len(classes)}')

# A dictionary which contains class and number of images in that class
counts = {}
for c in classes:
    counts[c] = len(os.listdir(os.path.join(path, c)))
    
print(f'Total number of images in dataset: {sum(list(counts.values()))}')

# Number of images in each clsss plot
fig = plt.figure(figsize = (25, 5))
sns.lineplot(x = list(counts.keys()), y = list(counts.values())).set_title('Number of images in each class')
plt.xticks(rotation = 90)
plt.margins(x=0)
plt.show()
# Out:
# Total number of categories: 149
# Total number of images in dataset: 10693

# %% [markdown]
# Well, as we can see, we have a deal with imbalanced dataset - 9 classes have a lot of pictures, another classes - very few. Moreover, as I said earlier, I tried to train model on all 149 classes, but my best results were 67% accuracy on train data and 54% on test data, we definetly need more data to train such model.
#
# So, in this case I decided to use another approach - I'll use only 5 classes with most number of pictures to train model:

# %%
# Sort our "counts" dictionary and selecting 5 classes with most number of images
imbalanced = sorted(counts.items(), key = lambda x: x[1], reverse = True)[:5]
print(imbalanced)

# Taking only labels, it will come in handy in future
imbalanced = [i[0] for i in imbalanced]
print(imbalanced)
# Out:
# [('Mewtwo', 307), ('Pikachu', 298), ('Charmander', 296), ('Bulbasaur', 289), ('Squirtle', 280)]
# ['Mewtwo', 'Pikachu', 'Charmander', 'Bulbasaur', 'Squirtle']

# %% [markdown]
# Now I want to read all images and add them to list:

# %%
X = [] # List for images
Y = [] # List for labels

# Loop through all classes
for c in classes:
    # We take only classes that we defined in 'imbalanced' list
    if c in imbalanced:
        dir_path = os.path.join(path, c)
        label = imbalanced.index(c) # Our label is an index of class in 'imbalanced' list
        
        # Reading, resizing and adding image and label to lists
        for i in os.listdir(dir_path):
            image = cv.imread(os.path.join(dir_path, i))
            
            try:
                resized = cv.resize(image, (96, 96)) # Resizing images to (96, 96)
                X.append(resized)
                Y.append(label)
            
            # If we can't read image - we skip it
            except:
                print(os.path.join(dir_path, i), '[ERROR] can\'t read the file')
                continue       
            
print('DONE')
# Out:
# ../input/pokemon-generation-one/dataset/dataset/Mewtwo/ed9eb0e7d3494c6992e06196f5b7cc05.svg [ERROR] can't read the file
# DONE

# %% [markdown]
# Let's look what we have now:

# %%
# Counting appearances of each label in labels list
obj = Counter(Y)

# Plotting number of images in each class
fig = plt.figure(figsize = (15, 5))
sns.barplot(x = [imbalanced[i] for i in obj.keys()], y = list(obj.values())).set_title('Number of images in each class')
plt.margins(x=0)
plt.show()

# %% [markdown]
# Now we have 5 classes, each with about 300 images.

# %%
# Convert list with images to numpy array and reshape it 
X = np.array(X).reshape(-1, 96, 96, 3)

# Scaling data in array
X = X / 255.0

# Convert labels to categorical format
y = to_categorical(Y, num_classes = len(imbalanced))

# Splitting data to train and test datasets
# I'll use these datasets only for training, for final predictions I'll use random pictures from internet
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, shuffle = True, random_state = 666)

# %% [markdown]
# Because we do not have too much data - we need to use data augmentation using ImageDataGenerator, which will apply random transformations to our images.

# %%
# Defining ImageDataGenerator Iinstance
datagen = ImageDataGenerator(rotation_range = 45, # Degree range for random rotations
                            zoom_range = 0.2, # Range for random zoom 
                            horizontal_flip = True, # Randomly flip inputs horizontally
                            width_shift_range = 0.15, # Range for horizontal shift 
                            height_shift_range = 0.15, # Range for vertical shift 
                            shear_range = 0.2) # Shear Intensity

datagen.fit(X_train)

# This piece of code can be used if you eant to look what your datagen doing with your images
# img = X[600]
# img = img.reshape([-1, 96, 96, 3])

# i = 0
# fig = plt.figure(figsize = (18, 8))

# for i, flow in enumerate(datagen.flow(img, batch_size = 1)):
#     fig.add_subplot(2, 5, i+1)
#     plt.imshow(np.squeeze(flow[:, :, ::-1]))
#     plt.axis('off')
#     i += 1
#     if i >= 10:
#         break

# %% [markdown]
# Now we can create our model, I'll use VGG-like architecture here:

# %%
model = Sequential()
model.add(Conv2D(32, 3, padding = 'same', activation = 'relu', input_shape =(96, 96, 3), kernel_initializer = 'he_normal'))
model.add(BatchNormalization(axis = -1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization(axis = -1))
model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization(axis = -1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization(axis = -1))
model.add(Conv2D(128, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization(axis = -1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization(axis = -1))
model.add(Conv2D(256, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization(axis = -1))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(len(imbalanced), activation = 'softmax'))

# model.summary()

checkpoint = ModelCheckpoint('../working/best_model.hdf5', verbose = 1, monitor = 'val_accuracy', save_best_only = True)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = 32), epochs = 100, validation_data = [X_test, y_test],
                             steps_per_epoch=len(X_train) // 32, callbacks = [checkpoint])
# Out:
# Epoch 1/100
# 36/36 [==============================] - 8s 213ms/step - loss: 1.5412 - accuracy: 0.5346 - val_loss: 1.8239 - val_accuracy: 0.4898
#
# Epoch 00001: val_accuracy improved from -inf to 0.48980, saving model to ../working/best_model.hdf5
# Epoch 2/100
# 36/36 [==============================] - 3s 84ms/step - loss: 1.0102 - accuracy: 0.6920 - val_loss: 0.7977 - val_accuracy: 0.6769
#
# Epoch 00002: val_accuracy improved from 0.48980 to 0.67687, saving model to ../working/best_model.hdf5
# Epoch 3/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.8495 - accuracy: 0.7472 - val_loss: 0.8547 - val_accuracy: 0.7449
#
# Epoch 00003: val_accuracy improved from 0.67687 to 0.74490, saving model to ../working/best_model.hdf5
# Epoch 4/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.7304 - accuracy: 0.7813 - val_loss: 0.7350 - val_accuracy: 0.7891
#
# Epoch 00004: val_accuracy improved from 0.74490 to 0.78912, saving model to ../working/best_model.hdf5
# Epoch 5/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.6619 - accuracy: 0.7839 - val_loss: 0.9991 - val_accuracy: 0.7313
#
# Epoch 00005: val_accuracy did not improve from 0.78912
# Epoch 6/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.5748 - accuracy: 0.8136 - val_loss: 1.1356 - val_accuracy: 0.7245
#
# Epoch 00006: val_accuracy did not improve from 0.78912
# Epoch 7/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.5974 - accuracy: 0.8186 - val_loss: 1.2155 - val_accuracy: 0.6837
#
# Epoch 00007: val_accuracy did not improve from 0.78912
# Epoch 8/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.4702 - accuracy: 0.8483 - val_loss: 0.6507 - val_accuracy: 0.8401
#
# Epoch 00008: val_accuracy improved from 0.78912 to 0.84014, saving model to ../working/best_model.hdf5
# Epoch 9/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.4727 - accuracy: 0.8486 - val_loss: 0.8423 - val_accuracy: 0.7857
#
# Epoch 00009: val_accuracy did not improve from 0.84014
# Epoch 10/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.4803 - accuracy: 0.8338 - val_loss: 0.4280 - val_accuracy: 0.8810
#
# Epoch 00010: val_accuracy improved from 0.84014 to 0.88095, saving model to ../working/best_model.hdf5
# Epoch 11/100
# 36/36 [==============================] - 3s 80ms/step - loss: 0.4892 - accuracy: 0.8390 - val_loss: 0.6526 - val_accuracy: 0.8163
#
# Epoch 00011: val_accuracy did not improve from 0.88095
# Epoch 12/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.3873 - accuracy: 0.8689 - val_loss: 0.4847 - val_accuracy: 0.8503
#
# Epoch 00012: val_accuracy did not improve from 0.88095
# Epoch 13/100
# 36/36 [==============================] - 3s 80ms/step - loss: 0.4649 - accuracy: 0.8422 - val_loss: 0.3396 - val_accuracy: 0.8878
#
# Epoch 00013: val_accuracy improved from 0.88095 to 0.88776, saving model to ../working/best_model.hdf5
# Epoch 14/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.3958 - accuracy: 0.8655 - val_loss: 0.3115 - val_accuracy: 0.9048
#
# Epoch 00014: val_accuracy improved from 0.88776 to 0.90476, saving model to ../working/best_model.hdf5
# Epoch 15/100
# 36/36 [==============================] - 3s 79ms/step - loss: 0.3696 - accuracy: 0.8862 - val_loss: 0.4976 - val_accuracy: 0.8265
#
# Epoch 00015: val_accuracy did not improve from 0.90476
# Epoch 16/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.3357 - accuracy: 0.8793 - val_loss: 0.3578 - val_accuracy: 0.8912
#
# Epoch 00016: val_accuracy did not improve from 0.90476
# Epoch 17/100
# 36/36 [==============================] - 3s 80ms/step - loss: 0.3601 - accuracy: 0.8766 - val_loss: 0.4945 - val_accuracy: 0.8605
#
# Epoch 00017: val_accuracy did not improve from 0.90476
# Epoch 18/100
# 36/36 [==============================] - 3s 81ms/step - loss: 0.3162 - accuracy: 0.8880 - val_loss: 0.5416 - val_accuracy: 0.8469
#
# Epoch 00018: val_accuracy did not improve from 0.90476
# Epoch 19/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.3730 - accuracy: 0.8819 - val_loss: 0.3074 - val_accuracy: 0.9150
#
# Epoch 00019: val_accuracy improved from 0.90476 to 0.91497, saving model to ../working/best_model.hdf5
# Epoch 20/100
# 36/36 [==============================] - 3s 80ms/step - loss: 0.3048 - accuracy: 0.8836 - val_loss: 0.3670 - val_accuracy: 0.9082
#
# Epoch 00020: val_accuracy did not improve from 0.91497
# Epoch 21/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.3240 - accuracy: 0.8906 - val_loss: 0.3320 - val_accuracy: 0.8912
#
# Epoch 00021: val_accuracy did not improve from 0.91497
# Epoch 22/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2832 - accuracy: 0.9004 - val_loss: 0.2893 - val_accuracy: 0.9320
#
# Epoch 00022: val_accuracy improved from 0.91497 to 0.93197, saving model to ../working/best_model.hdf5
# Epoch 23/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2829 - accuracy: 0.9090 - val_loss: 0.3500 - val_accuracy: 0.8878
#
# Epoch 00023: val_accuracy did not improve from 0.93197
# Epoch 24/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.3271 - accuracy: 0.8941 - val_loss: 0.4564 - val_accuracy: 0.8673
#
# Epoch 00024: val_accuracy did not improve from 0.93197
# Epoch 25/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2883 - accuracy: 0.8995 - val_loss: 0.3767 - val_accuracy: 0.8776
#
# Epoch 00025: val_accuracy did not improve from 0.93197
# Epoch 26/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.3071 - accuracy: 0.8984 - val_loss: 0.2541 - val_accuracy: 0.9354
#
# Epoch 00026: val_accuracy improved from 0.93197 to 0.93537, saving model to ../working/best_model.hdf5
# Epoch 27/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2811 - accuracy: 0.9081 - val_loss: 0.3063 - val_accuracy: 0.9184
#
# Epoch 00027: val_accuracy did not improve from 0.93537
# Epoch 28/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.2413 - accuracy: 0.9108 - val_loss: 0.3682 - val_accuracy: 0.8844
#
# Epoch 00028: val_accuracy did not improve from 0.93537
# Epoch 29/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2619 - accuracy: 0.9136 - val_loss: 0.2810 - val_accuracy: 0.9286
#
# Epoch 00029: val_accuracy did not improve from 0.93537
# Epoch 30/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2847 - accuracy: 0.9080 - val_loss: 0.4622 - val_accuracy: 0.8469
#
# Epoch 00030: val_accuracy did not improve from 0.93537
# Epoch 31/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2466 - accuracy: 0.9213 - val_loss: 0.3960 - val_accuracy: 0.8946
#
# Epoch 00031: val_accuracy did not improve from 0.93537
# Epoch 32/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2667 - accuracy: 0.9090 - val_loss: 0.2973 - val_accuracy: 0.9354
#
# Epoch 00032: val_accuracy did not improve from 0.93537
# Epoch 33/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2964 - accuracy: 0.8976 - val_loss: 0.3348 - val_accuracy: 0.9014
#
# Epoch 00033: val_accuracy did not improve from 0.93537
# Epoch 34/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2668 - accuracy: 0.9038 - val_loss: 0.3841 - val_accuracy: 0.8776
#
# Epoch 00034: val_accuracy did not improve from 0.93537
# Epoch 35/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2570 - accuracy: 0.9081 - val_loss: 0.4355 - val_accuracy: 0.8639
#
# Epoch 00035: val_accuracy did not improve from 0.93537
# Epoch 36/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.2785 - accuracy: 0.9116 - val_loss: 0.2798 - val_accuracy: 0.9116
#
# Epoch 00036: val_accuracy did not improve from 0.93537
# Epoch 37/100
# 36/36 [==============================] - 3s 80ms/step - loss: 0.2047 - accuracy: 0.9283 - val_loss: 0.2212 - val_accuracy: 0.9422
#
# Epoch 00037: val_accuracy improved from 0.93537 to 0.94218, saving model to ../working/best_model.hdf5
# Epoch 38/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.2225 - accuracy: 0.9230 - val_loss: 0.3920 - val_accuracy: 0.8776
#
# Epoch 00038: val_accuracy did not improve from 0.94218
# Epoch 39/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2304 - accuracy: 0.9178 - val_loss: 0.3496 - val_accuracy: 0.8878
#
# Epoch 00039: val_accuracy did not improve from 0.94218
# Epoch 40/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2026 - accuracy: 0.9248 - val_loss: 0.5367 - val_accuracy: 0.8469
#
# Epoch 00040: val_accuracy did not improve from 0.94218
# Epoch 41/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2035 - accuracy: 0.9344 - val_loss: 0.2832 - val_accuracy: 0.9048
#
# Epoch 00041: val_accuracy did not improve from 0.94218
# Epoch 42/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1868 - accuracy: 0.9361 - val_loss: 0.3546 - val_accuracy: 0.8844
#
# Epoch 00042: val_accuracy did not improve from 0.94218
# Epoch 43/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2442 - accuracy: 0.9256 - val_loss: 0.4322 - val_accuracy: 0.8844
#
# Epoch 00043: val_accuracy did not improve from 0.94218
# Epoch 44/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.2077 - accuracy: 0.9221 - val_loss: 0.2294 - val_accuracy: 0.9286
#
# Epoch 00044: val_accuracy did not improve from 0.94218
# Epoch 45/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1938 - accuracy: 0.9291 - val_loss: 0.2204 - val_accuracy: 0.9456
#
# Epoch 00045: val_accuracy improved from 0.94218 to 0.94558, saving model to ../working/best_model.hdf5
# Epoch 46/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1939 - accuracy: 0.9300 - val_loss: 0.3461 - val_accuracy: 0.9150
#
# Epoch 00046: val_accuracy did not improve from 0.94558
# Epoch 47/100
# 36/36 [==============================] - 3s 89ms/step - loss: 0.1800 - accuracy: 0.9306 - val_loss: 0.4593 - val_accuracy: 0.8776
#
# Epoch 00047: val_accuracy did not improve from 0.94558
# Epoch 48/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2101 - accuracy: 0.9339 - val_loss: 0.4879 - val_accuracy: 0.8707
#
# Epoch 00048: val_accuracy did not improve from 0.94558
# Epoch 49/100
# 36/36 [==============================] - 3s 87ms/step - loss: 0.1972 - accuracy: 0.9384 - val_loss: 0.2351 - val_accuracy: 0.9286
#
# Epoch 00049: val_accuracy did not improve from 0.94558
# Epoch 50/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1884 - accuracy: 0.9466 - val_loss: 0.2589 - val_accuracy: 0.9286
#
# Epoch 00050: val_accuracy did not improve from 0.94558
# Epoch 51/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2066 - accuracy: 0.9242 - val_loss: 0.5227 - val_accuracy: 0.8605
#
# Epoch 00051: val_accuracy did not improve from 0.94558
# Epoch 52/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.2162 - accuracy: 0.9405 - val_loss: 0.4837 - val_accuracy: 0.8776
#
# Epoch 00052: val_accuracy did not improve from 0.94558
# Epoch 53/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1732 - accuracy: 0.9392 - val_loss: 0.2422 - val_accuracy: 0.9252
#
# Epoch 00053: val_accuracy did not improve from 0.94558
# Epoch 54/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1850 - accuracy: 0.9347 - val_loss: 0.4030 - val_accuracy: 0.8980
#
# Epoch 00054: val_accuracy did not improve from 0.94558
# Epoch 55/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1979 - accuracy: 0.9370 - val_loss: 0.4595 - val_accuracy: 0.8571
#
# Epoch 00055: val_accuracy did not improve from 0.94558
# Epoch 56/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1674 - accuracy: 0.9470 - val_loss: 0.2816 - val_accuracy: 0.9218
#
# Epoch 00056: val_accuracy did not improve from 0.94558
# Epoch 57/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1844 - accuracy: 0.9409 - val_loss: 0.3146 - val_accuracy: 0.9116
#
# Epoch 00057: val_accuracy did not improve from 0.94558
# Epoch 58/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1748 - accuracy: 0.9370 - val_loss: 0.5045 - val_accuracy: 0.8639
#
# Epoch 00058: val_accuracy did not improve from 0.94558
# Epoch 59/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1972 - accuracy: 0.9353 - val_loss: 0.2288 - val_accuracy: 0.9320
#
# Epoch 00059: val_accuracy did not improve from 0.94558
# Epoch 60/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1884 - accuracy: 0.9375 - val_loss: 0.2829 - val_accuracy: 0.9082
#
# Epoch 00060: val_accuracy did not improve from 0.94558
# Epoch 61/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1522 - accuracy: 0.9449 - val_loss: 0.2885 - val_accuracy: 0.9048
#
# Epoch 00061: val_accuracy did not improve from 0.94558
# Epoch 62/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2018 - accuracy: 0.9326 - val_loss: 0.4216 - val_accuracy: 0.8878
#
# Epoch 00062: val_accuracy did not improve from 0.94558
# Epoch 63/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2275 - accuracy: 0.9198 - val_loss: 0.5386 - val_accuracy: 0.8605
#
# Epoch 00063: val_accuracy did not improve from 0.94558
# Epoch 64/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2141 - accuracy: 0.9271 - val_loss: 0.5888 - val_accuracy: 0.8469
#
# Epoch 00064: val_accuracy did not improve from 0.94558
# Epoch 65/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1828 - accuracy: 0.9405 - val_loss: 0.2331 - val_accuracy: 0.9218
#
# Epoch 00065: val_accuracy did not improve from 0.94558
# Epoch 66/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.2081 - accuracy: 0.9344 - val_loss: 0.2566 - val_accuracy: 0.9218
#
# Epoch 00066: val_accuracy did not improve from 0.94558
# Epoch 67/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1852 - accuracy: 0.9318 - val_loss: 0.3110 - val_accuracy: 0.8776
#
# Epoch 00067: val_accuracy did not improve from 0.94558
# Epoch 68/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1550 - accuracy: 0.9466 - val_loss: 0.3995 - val_accuracy: 0.8810
#
# Epoch 00068: val_accuracy did not improve from 0.94558
# Epoch 69/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1467 - accuracy: 0.9462 - val_loss: 0.2243 - val_accuracy: 0.9354
#
# Epoch 00069: val_accuracy did not improve from 0.94558
# Epoch 70/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1609 - accuracy: 0.9436 - val_loss: 0.2447 - val_accuracy: 0.9354
#
# Epoch 00070: val_accuracy did not improve from 0.94558
# Epoch 71/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1660 - accuracy: 0.9458 - val_loss: 0.4728 - val_accuracy: 0.8707
#
# Epoch 00071: val_accuracy did not improve from 0.94558
# Epoch 72/100
# 36/36 [==============================] - 3s 87ms/step - loss: 0.1661 - accuracy: 0.9458 - val_loss: 0.2736 - val_accuracy: 0.9150
#
# Epoch 00072: val_accuracy did not improve from 0.94558
# Epoch 73/100
# 36/36 [==============================] - 3s 87ms/step - loss: 0.1548 - accuracy: 0.9449 - val_loss: 0.2675 - val_accuracy: 0.9354
#
# Epoch 00073: val_accuracy did not improve from 0.94558
# Epoch 74/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1527 - accuracy: 0.9501 - val_loss: 0.9632 - val_accuracy: 0.7551
#
# Epoch 00074: val_accuracy did not improve from 0.94558
# Epoch 75/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1629 - accuracy: 0.9431 - val_loss: 0.2326 - val_accuracy: 0.9252
#
# Epoch 00075: val_accuracy did not improve from 0.94558
# Epoch 76/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1304 - accuracy: 0.9510 - val_loss: 0.4050 - val_accuracy: 0.8946
#
# Epoch 00076: val_accuracy did not improve from 0.94558
# Epoch 77/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1439 - accuracy: 0.9545 - val_loss: 0.3357 - val_accuracy: 0.9150
#
# Epoch 00077: val_accuracy did not improve from 0.94558
# Epoch 78/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1699 - accuracy: 0.9475 - val_loss: 0.3773 - val_accuracy: 0.9014
#
# Epoch 00078: val_accuracy did not improve from 0.94558
# Epoch 79/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1611 - accuracy: 0.9431 - val_loss: 0.2587 - val_accuracy: 0.9354
#
# Epoch 00079: val_accuracy did not improve from 0.94558
# Epoch 80/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1396 - accuracy: 0.9519 - val_loss: 0.4327 - val_accuracy: 0.8503
#
# Epoch 00080: val_accuracy did not improve from 0.94558
# Epoch 81/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1423 - accuracy: 0.9444 - val_loss: 0.2250 - val_accuracy: 0.9218
#
# Epoch 00081: val_accuracy did not improve from 0.94558
# Epoch 82/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1374 - accuracy: 0.9533 - val_loss: 0.5495 - val_accuracy: 0.8571
#
# Epoch 00082: val_accuracy did not improve from 0.94558
# Epoch 83/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1728 - accuracy: 0.9431 - val_loss: 0.5339 - val_accuracy: 0.8265
#
# Epoch 00083: val_accuracy did not improve from 0.94558
# Epoch 84/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1678 - accuracy: 0.9466 - val_loss: 0.3794 - val_accuracy: 0.8776
#
# Epoch 00084: val_accuracy did not improve from 0.94558
# Epoch 85/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1659 - accuracy: 0.9440 - val_loss: 0.2457 - val_accuracy: 0.9286
#
# Epoch 00085: val_accuracy did not improve from 0.94558
# Epoch 86/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.0985 - accuracy: 0.9668 - val_loss: 0.2705 - val_accuracy: 0.9252
#
# Epoch 00086: val_accuracy did not improve from 0.94558
# Epoch 87/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1265 - accuracy: 0.9627 - val_loss: 0.2525 - val_accuracy: 0.9320
#
# Epoch 00087: val_accuracy did not improve from 0.94558
# Epoch 88/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1346 - accuracy: 0.9577 - val_loss: 0.2926 - val_accuracy: 0.9252
#
# Epoch 00088: val_accuracy did not improve from 0.94558
# Epoch 89/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1485 - accuracy: 0.9528 - val_loss: 0.2933 - val_accuracy: 0.9082
#
# Epoch 00089: val_accuracy did not improve from 0.94558
# Epoch 90/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1201 - accuracy: 0.9554 - val_loss: 0.2768 - val_accuracy: 0.9286
#
# Epoch 00090: val_accuracy did not improve from 0.94558
# Epoch 91/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.0984 - accuracy: 0.9650 - val_loss: 0.2418 - val_accuracy: 0.9388
#
# Epoch 00091: val_accuracy did not improve from 0.94558
# Epoch 92/100
# 36/36 [==============================] - 3s 84ms/step - loss: 0.1249 - accuracy: 0.9557 - val_loss: 0.3123 - val_accuracy: 0.9184
#
# Epoch 00092: val_accuracy did not improve from 0.94558
# Epoch 93/100
# 36/36 [==============================] - 4s 102ms/step - loss: 0.1075 - accuracy: 0.9598 - val_loss: 0.2153 - val_accuracy: 0.9320
#
# Epoch 00093: val_accuracy did not improve from 0.94558
# Epoch 94/100
# 36/36 [==============================] - 3s 86ms/step - loss: 0.1199 - accuracy: 0.9647 - val_loss: 0.3850 - val_accuracy: 0.9048
#
# Epoch 00094: val_accuracy did not improve from 0.94558
# Epoch 95/100
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1420 - accuracy: 0.9545 - val_loss: 0.2693 - val_accuracy: 0.9422
#
# Epoch 00095: val_accuracy did not improve from 0.94558
# Epoch 96/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1354 - accuracy: 0.9618 - val_loss: 0.3311 - val_accuracy: 0.9014
#
# Epoch 00096: val_accuracy did not improve from 0.94558
# Epoch 97/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1429 - accuracy: 0.9554 - val_loss: 0.2550 - val_accuracy: 0.9286
#
# Epoch 00097: val_accuracy did not improve from 0.94558
# Epoch 98/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.1499 - accuracy: 0.9528 - val_loss: 0.3498 - val_accuracy: 0.9252
#
# Epoch 00098: val_accuracy did not improve from 0.94558
# Epoch 99/100
# 36/36 [==============================] - 3s 82ms/step - loss: 0.1551 - accuracy: 0.9449 - val_loss: 0.2725 - val_accuracy: 0.9388
#
# Epoch 00099: val_accuracy did not improve from 0.94558
# Epoch 100/100
# 36/36 [==============================] - 3s 83ms/step - loss: 0.1308 - accuracy: 0.9528 - val_loss: 0.2866 - val_accuracy: 0.9354
#
# Epoch 00100: val_accuracy did not improve from 0.94558

# %% [markdown]
# Well, looks like we have a best accuracy on 66th epoch - 94.558%.

# %%
# Plot learning curves
fig = plt.figure(figsize = (17, 4))
    
plt.subplot(121)
plt.plot(history.history['accuracy'], label = 'acc')
plt.plot(history.history['val_accuracy'], label = 'val_acc')
plt.legend()
plt.grid()
plt.title(f'accuracy')

plt.subplot(122)
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.legend()
plt.grid()
plt.title(f'loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
# Loading weights from best model
model.load_weights('../working/best_model.hdf5')

# Saving all model
model.save('../working/model.hdf5')

# %% [markdown]
# Now we can predict some unseen data. In this kernel I want to stick to a little bit unusual approach - I want to take some random pictures for each class from internet and try to predict them, so I quikly grabbed some urls from Google images and put them in lists:

# %%
mewtwo = ['https://cdn.bulbagarden.net/upload/thumb/7/78/150Mewtwo.png/250px-150Mewtwo.png',
         'https://cdn.vox-cdn.com/thumbor/sZPPvUyKyF97UEU-nNtVnC3LpF8=/0x0:1750x941/1200x800/filters:focal(878x316:1158x596)/cdn.vox-cdn.com/uploads/chorus_image/image/63823444/original.0.jpg',
         'https://images-na.ssl-images-amazon.com/images/I/61j5ozFjJ0L._SL1024_.jpg']

pikachu = ['https://lh3.googleusercontent.com/proxy/DrjDlKlu9YonKbj3iNCJNJ3DGqzy9GjeXXSUv-TcVV4UN9PMCAM5yIkGLPG7wYo3UeA4sq5OmUWM8M6K5hy2KOAhf8SOL3zPH3axb2Xo3HX2XTU8M2xW4X6lVg=w720-h405-rw',
          'https://giantbomb1.cbsistatic.com/uploads/scale_medium/0/6087/2437349-pikachu.png',
          'https://johnlewis.scene7.com/is/image/JohnLewis/237525467']

charmander = ['https://img.pokemondb.net/artwork/large/charmander.jpg',
             'https://www.pokemoncenter.com/wcsstore/PokemonCatalogAssetStore/images/catalog/products/P5073/701-03990/P5073_701-03990_01.jpg',
             'https://static.posters.cz/image/750/%D0%A7%D0%B0%D1%88%D0%BA%D0%B0/pokemon-charmander-glow-i72513.jpg']

bulbasaur = ['https://img.pokemondb.net/artwork/large/bulbasaur.jpg',
            'https://ae01.alicdn.com/kf/HTB1aWullxSYBuNjSsphq6zGvVXaR/Big-Size-55-CM-Plush-Toy-Squirtle-Bulbasaur-Charmander-Toy-Sleeping-Pillow-Doll-For-Kid-Birthday.jpg',
            'https://cdn.bulbagarden.net/upload/thumb/f/f7/Bulbasaur_Detective_Pikachu.jpg/250px-Bulbasaur_Detective_Pikachu.jpg']

squirtle = ['https://assets.pokemon.com/assets/cms2/img/pokedex/full/007.png',
           'https://cdn.vox-cdn.com/thumbor/l4cKX7ZWargjs-zlxOSW2WZVgfI=/0x0:2040x1360/1200x800/filters:focal(857x517:1183x843)/cdn.vox-cdn.com/uploads/chorus_image/image/61498573/jbareham_180925_ply0802_0030.1537570476.jpg',
           'https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Fdavidthier%2Ffiles%2F2018%2F07%2FSquirtle_Squad.jpg']

test_df = [mewtwo, pikachu, charmander, bulbasaur, squirtle]

# %% [markdown]
# Now I need to transform these urls to arrays of numbers:

# %%
# Lists to store our future data
val_x = []
val_y = []

for i, urls in enumerate(test_df):
    for url in urls:        
        r = requests.get(url, stream = True).raw
        image = np.asarray(bytearray(r.read()), dtype="uint8")
        image = cv.imdecode(image, cv.IMREAD_COLOR)
        val_x.append(image)
        val_y.append(i)

# plt.imshow(image[:, :, ::-1])

# %% [markdown]
# And now we can finaly make our predictions:

# %%
rows = 5
cols = 3

fig = plt.figure(figsize = (25, 25))

for i, j in enumerate(zip(val_x, val_y)): # i - for subplots
    orig = j[0] # Original, not resized image
    label = j[1] # Label for that image
    
    image = cv.resize(orig, (96, 96)) # Resizing image to (96, 96)
    image = image.reshape(-1, 96, 96, 3) / 255.0 # Reshape and scale resized image
    preds = model.predict(image) # Predicting image
    pred_class = np.argmax(preds) # Defining predicted class
    
    true_label = f'True class: {imbalanced[label]}'
    pred_label = f'Predicted: {imbalanced[pred_class]} {round(preds[0][pred_class] * 100, 2)}%'
    
    fig.add_subplot(rows, cols, i+1)
    plt.imshow(orig[:, :, ::-1])
    plt.title(f'{true_label}\n{pred_label}')
    plt.axis('off')
    
plt.tight_layout()

# %% [markdown]
# Well, we have 2 mistakes - Pikachu from Detective Pikachu movie was incorectly classified as Charmander and Bulbasaur (again from same move) was incorrectly classified as Mewtwo, in all other cases we got pretty good results and I think that it's not bad for such small dataset.
#
# I hope this kernel was useful, please vote if you like it and good luck in your machine learning journey.
